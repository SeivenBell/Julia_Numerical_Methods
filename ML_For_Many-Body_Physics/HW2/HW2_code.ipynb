# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Example data: Replace this with your actual data loading code
X = np.random.rand(100, 100)  # 100 samples, each with 100 dimensions

# Apply t-SNE
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
X_tsne = tsne.fit_transform(X)

# Plot the result
plt.scatter(X_tsne[:, 0], X_tsne[:, 1])
plt.title("t-SNE results")
plt.show()
# Out:
# [t-SNE] Computing 99 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.000s...
# [t-SNE] Computed neighbors for 100 samples in 0.268s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 1.097982
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.147999
# [t-SNE] KL divergence after 300 iterations: 0.701993
